# %%
import pandas as pd 
import numpy as np

# %%
dados=pd.read_csv('ArmasApreendidasEvolucaoCisp.csv', sep=';')
display(dados.head())
# Out:
#    cisp  mes   ano  aisp  risp  arma_fogo_arma_fabricacao_caseira  \
# 0     1    1  2007     5     1                                  0
# 1     1    2  2007     5     1                                  0
# 2     1    3  2007     5     1                                  0
# 3     1    4  2007     5     1                                  0
# 4     1    5  2007     5     1                                  0
#
#    arma_fogo_carabina  arma_fogo_espingarda  arma_fogo_fuzil  \
# 0                   0                     0                0
# 1                   0                     0                0
# 2                   0                     0                0
# 3                   0                     0                0
# 4                   0                     0                0
#
#    arma_fogo_garrucha  ...  simulacro_fuzil  simulacro_garrucha  \
# 0                   0  ...              NaN                 NaN
# 1                   0  ...              NaN                 NaN
# ...

# %%
estatisca=dados.describe()
display(estatisca)
# Out:
#                cisp           mes           ano          aisp          risp  \
# count  29736.000000  29736.000000  29736.000000  29736.000000  29736.000000
# mean      81.581114      6.500000   2015.485472     20.701170      3.854722
# std       48.297678      3.452111      5.185393     11.415816      2.011673
# min        1.000000      1.000000   2007.000000      2.000000      1.000000
# 25%       38.000000      3.750000   2011.000000     10.000000      2.000000
# 50%       78.000000      6.500000   2015.000000     21.000000      4.000000
# 75%      125.000000      9.250000   2020.000000     31.000000      6.000000
# max      168.000000     12.000000   2024.000000     43.000000      7.000000
#
#        arma_fogo_arma_fabricacao_caseira  arma_fogo_carabina  \
# count                       29736.000000        29736.000000
# mean                            0.089689            0.054580
# std                             0.730875            0.285424
# ...

# %%
df_copia=dados.copy()
display(df_copia)
# Out:
#        cisp  mes   ano  aisp  risp  arma_fogo_arma_fabricacao_caseira  \
# 0         1    1  2007     5     1                                  0
# 1         1    2  2007     5     1                                  0
# 2         1    3  2007     5     1                                  0
# 3         1    4  2007     5     1                                  0
# 4         1    5  2007     5     1                                  0
# ...     ...  ...   ...   ...   ...                                ...
# 29731   168    8  2024    28     5                                  0
# 29732   168    9  2024    28     5                                  0
# 29733   168   10  2024    28     5                                  0
# 29734   168   11  2024    28     5                                  0
# 29735   168   12  2024    28     5                                  0
#
#        arma_fogo_carabina  arma_fogo_espingarda  arma_fogo_fuzil  \
# ...
